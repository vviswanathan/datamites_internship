# %%
#Load raw data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from pandas import read_csv
df1=pd.read_csv("/Users/Lenovo/Desktop/Machine learning internship/Project/bank.csv")

# %% [markdown]
# There are 41,188 observations in the dataset.Each represent an existing customer that the bank reached via phone calls.
# For each customer there are 16 input variables(both numeric and categorical)
# There is a single binary output variable that reveals "yes" or "no" that denotes the outcomes of the phone calls

# %%
df1.head(5000)
# Out:
#       age            job   marital  education default  balance housing loan  \
# 0      59         admin.   married  secondary      no     2343     yes   no
# 1      56         admin.   married  secondary      no       45      no   no
# 2      41     technician   married  secondary      no     1270     yes   no
# 3      55       services   married  secondary      no     2476     yes   no
# 4      54         admin.   married   tertiary      no      184      no   no
# 5      42     management    single   tertiary      no        0     yes  yes
# 6      56     management   married   tertiary      no      830     yes  yes
# 7      60        retired  divorced  secondary      no      545     yes   no
# 8      37     technician   married  secondary      no        1     yes   no
# 9      28       services    single  secondary      no     5090     yes   no
# 10     38         admin.    single  secondary      no      100     yes   no
# ...

# %% [markdown]
# Cleaning the data
#
# 1.Deal with missing values

# %%
#Delete the rows of coloumn poutcome which contains 'other'

condition=df1.poutcome=='other'
df2=df1.drop(df1[condition].index,axis=0,inplace=False)

# %%
df2.head(5000)
# Out:
#       age            job   marital  education default  balance housing loan  \
# 0      59         admin.   married  secondary      no     2343     yes   no
# 1      56         admin.   married  secondary      no       45      no   no
# 2      41     technician   married  secondary      no     1270     yes   no
# 3      55       services   married  secondary      no     2476     yes   no
# 4      54         admin.   married   tertiary      no      184      no   no
# 5      42     management    single   tertiary      no        0     yes  yes
# 6      56     management   married   tertiary      no      830     yes  yes
# 7      60        retired  divorced  secondary      no      545     yes   no
# 8      37     technician   married  secondary      no        1     yes   no
# 9      28       services    single  secondary      no     5090     yes   no
# 10     38         admin.    single  secondary      no      100     yes   no
# ...

# %%
#Fill 'unknown' in job and education to 'other'

df2[['job','education']]= df2[['job','education']].replace(['unknown'],'other')

# %%
df2.head(5000)
# Out:
#       age            job   marital  education default  balance housing loan  \
# 0      59         admin.   married  secondary      no     2343     yes   no
# 1      56         admin.   married  secondary      no       45      no   no
# 2      41     technician   married  secondary      no     1270     yes   no
# 3      55       services   married  secondary      no     2476     yes   no
# 4      54         admin.   married   tertiary      no      184      no   no
# 5      42     management    single   tertiary      no        0     yes  yes
# 6      56     management   married   tertiary      no      830     yes  yes
# 7      60        retired  divorced  secondary      no      545     yes   no
# 8      37     technician   married  secondary      no        1     yes   no
# 9      28       services    single  secondary      no     5090     yes   no
# 10     38         admin.    single  secondary      no      100     yes   no
# ...

# %% [markdown]
# 2.Drop the outliers from the column 'balance'

# %%
from scipy.stats import zscore

df2[['balance']].mean()

df2['balance_outliers']=df2['balance']
df2['balance_outliers']=zscore(df2['balance_outliers'])

condition1=(df2['balance_outliers']>3) | (df2['balance_outliers']<-3)

df3= df2.drop(df2[condition1].index,axis=0,inplace=False)

# %%
df4=df3.drop('balance_outliers',axis=1)


#2556 rows of data were removed

# %%
df4.head(50)
# Out:
#     age           job   marital  education default  balance housing loan  \
# 0    59        admin.   married  secondary      no     2343     yes   no
# 1    56        admin.   married  secondary      no       45      no   no
# 2    41    technician   married  secondary      no     1270     yes   no
# 3    55      services   married  secondary      no     2476     yes   no
# 4    54        admin.   married   tertiary      no      184      no   no
# 5    42    management    single   tertiary      no        0     yes  yes
# 6    56    management   married   tertiary      no      830     yes  yes
# 7    60       retired  divorced  secondary      no      545     yes   no
# 8    37    technician   married  secondary      no        1     yes   no
# 9    28      services    single  secondary      no     5090     yes   no
# 10   38        admin.    single  secondary      no      100     yes   no
# 11   30   blue-collar   married  secondary      no      309     yes   no
# ...

# %% [markdown]
# 3.Creating and Transforming data

# %%
#change deposit to response

df4.rename(index=str, columns={'deposit': 'response'}, inplace = True)

def convert(df4, new_column, old_column):
    df4[new_column] = df4[old_column].apply(lambda x: 0 if x == 'no' else 1)
    return df4[new_column].value_counts()

convert(df4, "response_binary", "response")
# Out:
# 0    5568
# 1    4879
# Name: response_binary, dtype: int64

# %%
#Drop contact which is useless

df5=df4.drop('contact',axis=1)

# %%
df5.head()
# Out:
#    age         job  marital  education default  balance housing loan  day  \
# 0   59      admin.  married  secondary      no     2343     yes   no    5
# 1   56      admin.  married  secondary      no       45      no   no    5
# 2   41  technician  married  secondary      no     1270     yes   no    5
# 3   55    services  married  secondary      no     2476     yes   no    5
# 4   54      admin.  married   tertiary      no      184      no   no    5
#
#   month  duration  campaign  pdays  previous poutcome response  \
# 0   may      1042         1     -1         0  unknown      yes
# 1   may      1467         1     -1         0  unknown      yes
# 2   may      1389         1     -1         0  unknown      yes
# 3   may       579         1     -1         0  unknown      yes
# 4   may       673         2     -1         0  unknown      yes
#
#    response_binary
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
#unit of duration changed from seconds to minutes

df5['duration']=df5['duration'].apply (lambda n:n/60).round(2)

# %%
df5.head()
# Out:
#    age         job  marital  education default  balance housing loan  day  \
# 0   59      admin.  married  secondary      no     2343     yes   no    5
# 1   56      admin.  married  secondary      no       45      no   no    5
# 2   41  technician  married  secondary      no     1270     yes   no    5
# 3   55    services  married  secondary      no     2476     yes   no    5
# 4   54      admin.  married   tertiary      no      184      no   no    5
#
#   month  duration  campaign  pdays  previous poutcome response  \
# 0   may     17.37         1     -1         0  unknown      yes
# 1   may     24.45         1     -1         0  unknown      yes
# 2   may     23.15         1     -1         0  unknown      yes
# 3   may      9.65         1     -1         0  unknown      yes
# 4   may     11.22         2     -1         0  unknown      yes
#
#    response_binary
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
#change month from words to numbers

my_list=[df5]
for column in my_list:
    column.loc[column["month"] == "jan","month_int"]=1
    column.loc[column["month"] == "feb","month_int"]=2
    column.loc[column["month"] == "mar","month_int"]=3
    column.loc[column["month"] == "apr","month_int"]=4
    column.loc[column["month"] == "may","month_int"]=5
    column.loc[column["month"] == "jun","month_int"]=6
    column.loc[column["month"] == "jul","month_int"]=7
    column.loc[column["month"] == "aug","month_int"]=8
    column.loc[column["month"] == "sep","month_int"]=9
    column.loc[column["month"] == "oct","month_int"]=10
    column.loc[column["month"] == "nov","month_int"]=11
    column.loc[column["month"] == "dec","month_int"]=12

# %%
df5.head()
# Out:
#    age         job  marital  education default  balance housing loan  day  \
# 0   59      admin.  married  secondary      no     2343     yes   no    5
# 1   56      admin.  married  secondary      no       45      no   no    5
# 2   41  technician  married  secondary      no     1270     yes   no    5
# 3   55    services  married  secondary      no     2476     yes   no    5
# 4   54      admin.  married   tertiary      no      184      no   no    5
#
#   month  duration  campaign  pdays  previous poutcome response  \
# 0   may     17.37         1     -1         0  unknown      yes
# 1   may     24.45         1     -1         0  unknown      yes
# 2   may     23.15         1     -1         0  unknown      yes
# 3   may      9.65         1     -1         0  unknown      yes
# 4   may     11.22         2     -1         0  unknown      yes
#
#    response_binary  month_int
# 0                1        5.0
# 1                1        5.0
# 2                1        5.0
# ...

# %% [markdown]
# 4.FIltering

# %%
#drop rows with duration<5s

condition2=(df5["duration"]<5/60)
df6=df5.drop(df5[condition2].index,axis=0,inplace=False)

# %%
#drop customer values with other education

condition3=(df6["education"]=="other")
df7=df6.drop(df6[condition3].index,axis=0,inplace=False)

# %%
df7.head(50)
# Out:
#     age           job   marital  education default  balance housing loan  day  \
# 0    59        admin.   married  secondary      no     2343     yes   no    5
# 1    56        admin.   married  secondary      no       45      no   no    5
# 2    41    technician   married  secondary      no     1270     yes   no    5
# 3    55      services   married  secondary      no     2476     yes   no    5
# 4    54        admin.   married   tertiary      no      184      no   no    5
# 5    42    management    single   tertiary      no        0     yes  yes    5
# 6    56    management   married   tertiary      no      830     yes  yes    6
# 7    60       retired  divorced  secondary      no      545     yes   no    6
# 8    37    technician   married  secondary      no        1     yes   no    6
# 9    28      services    single  secondary      no     5090     yes   no    6
# 10   38        admin.    single  secondary      no      100     yes   no    7
# ...

# %% [markdown]
# Visualization

# %%
#plot distribution of 'age' and 'balance'

age_bal=plt.figure(figsize=(10,6))

r1= age_bal.add_subplot(121)
r2= age_bal.add_subplot(122)

r1.hist(df7["age"])
r1.set_title("Age distribution")

r2.hist(df7["balance"], color='pink')
r2.set_title("Balance Distribution")

plt.tight_layout()
plt.show()

# %%
#Visualize relation between age and balance

rel_age_bal=df7.plot.scatter('age','balance',color='green')
plt.title('Relation between age and balance of customers')
plt.show()

# %%
# plot distribution of duration and campaign

dur_camp = df7[['duration','campaign']].plot(kind = 'box',showmeans=True,figsize = (10,10),title='The Distribution of Duration and Campaign')
plt.show()

# %%
#relationship between duration and campaign

import seaborn as sns

dur_camp= sns.lmplot(x='duration',y='campaign',hue='response',data=df7,fit_reg=False,palette=['indigo','red'])
plt.axis([0,55,0,55])
plt.xlabel('Duration of calls in minutes')
plt.ylabel('Number of calls')
plt.title('Relation between number and duration of calls along with response')
plt.show()

# %%
#Correlation matrix with quantitative variables

corr_data = df7[['age','balance','duration','campaign','month_int','previous','response_binary']]
corr = corr_data.corr()

cor_plot = sns.heatmap(corr,annot=True,cmap='Blues_r',linewidths=0.2,annot_kws={'size':10})
fig=plt.gcf()

plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Campaign outcome has strong correlation with Response,moderate with previous contacts and mild with balance,month of contact and duration
#
# Further analysis of each customer characteristic is carried out to investigate the subscription rate

# %%
#visualize subscription and contact rate by age

my_list=[df7]
for column in my_list:
    column.loc[column["age"]<30,"agegroup"]=20
    column.loc[(column["age"]>=30) & (column["age"]<=39),"agegroup"]=30
    column.loc[(column["age"]>=40) & (column["age"]<=49),"agegroup"]=40
    column.loc[(column["age"]>=50) & (column["age"]<=59),"agegroup"]=50
    column.loc[column["age"]>=60,"agegroup"]=60

# %%
count_age_response = pd.crosstab(df7['response'],df7['agegroup']).apply(lambda x: x/x.sum() * 100)
count_age_response = count_age_response.transpose()

# %%
age = pd.DataFrame(df7['agegroup'].value_counts())
age['Contacts'] = age['agegroup']*100/age['agegroup'].sum()
age['Subscription'] = count_age_response['yes']
age.drop('agegroup',axis = 1,inplace = True)

age['age'] = [30,40,50,20,60]
age = age.sort_values('age',ascending = True)

# %%
plot_age = age[['Subscription','Contacts']].plot(kind = 'bar',
                                              figsize=(10,10), color = ('blue','black'))
plt.xlabel('Age Group')
plt.ylabel('Subscription Rate')
plt.title('Subscription VS. Contacts by Age')
plt.xticks(rotation = 'horizontal')
plt.show()

# %% [markdown]
# Customers with age groups 20s and 60s need to be contacted more often. They have contributed for more than 50 percent of subscriptions.
#
# Deposits are preferable to the eldest as they save more after retirement.
# Similarly the youngest prefer deposits as those are ideal investments for them since they dont have enough money to engage in other investments like mutual funds.
#
# So the bank should target the customers belonging to age-group 20s and 60s more in order to make the campaign more effective

# %%
#Visualize the subscription rate by balance level

my_list1 = [df7]
for column in my_list1:
    column.loc[column["balance"] <= 0,  'balance_group'] = 'zero balance'
    column.loc[(column["balance"] > 0) & (column["balance"] <= 1000), 'balance_group'] = 'low balance'
    column.loc[(column["balance"] > 1000) & (column["balance"] <= 5000), 'balance_group'] = 'standard balance'
    column.loc[(column["balance"] > 5000), 'balance_group'] = 'high balance'

# %%
count_balance_response = pd.crosstab(df7['response'],df7['balance_group']).apply(lambda x: x/x.sum() * 100)
count_balance_response = count_balance_response.transpose()

# %%
bal = pd.DataFrame(df7['balance_group'].value_counts())
bal['Contacts'] = bal['balance_group']*100/bal['balance_group'].sum()
bal['Subscription'] = count_balance_response['yes']
bal.drop('balance_group',axis = 1,inplace = True)

bal['bal'] = [1,2,0,3]
bal = bal.sort_values('bal',ascending = True)

# %%
plot_balance = bal[['Subscription','Contacts']].plot(kind = 'bar',
                                               color = ('orange','purple'),
                                               figsize = (10,10))

plt.title('Subscription vs Contact Rate by Balance Level')
plt.ylabel('Subscription')
plt.xlabel('Balance Category')
plt.xticks(rotation = 'horizontal')
plt.show()

# %% [markdown]
# Comparing the balance categories, it is clear that customers with high and standard balance should be focused more as they have majorly contributed to the subscription rate.

# %%
#Visualize the subscription rate by age and balance

age_balance1 = pd.DataFrame(df7.groupby(['agegroup','balance_group'])['response_binary'].sum())
age_balance2 = pd.DataFrame(df7.groupby(['agegroup','balance_group'])['response'].count())

age_balance1['response'] = age_balance2['response']
age_balance1['response_rate'] = age_balance1['response_binary']/ (age_balance1['response'])
age_balance1 = age_balance1.drop(['response_binary','response'],axis =1)

age_balance1 = age_balance1.unstack()

# %%
age_bal = age_balance1.plot(kind='bar',figsize = (10,10),color=('indigo','purple','royalblue','skyblue'))

plt.xticks(np.arange(5),('<30', '30-39', '40-49', '50-59', '60+'),rotation = 'horizontal')

plt.legend(['High Balance','Standard balance','Low Balance','No Balance'],loc = 'best',ncol = 1)

plt.ylabel('Subscriptions')
plt.xlabel('Age Group')
plt.title('The Subscription Rate of Different Balance Levels in Each Age Group')
plt.show()

# %% [markdown]
# When compared on the basis of age group, the people with age<30 and people with age>60 have higher subscription rate.
# Further observing the balance level in each age group, it is clear that bank should target mostly the younger and elder clients having positive balances.

# %%
#Visualize the subscription rate by job

count_job_response = pd.crosstab(df7['response'],df7['job']).apply(lambda x: x/x.sum() * 100)
count_job_response = count_job_response.transpose()

# %%
plot_job = count_job_response['yes'].sort_values(ascending = True).plot(kind ='barh',
                                                                           figsize = (12,6))
                                                                               
plt.title('Subscription Rate by Job')
plt.xlabel('Subscription Rate')
plt.ylabel('Job Category')
# Out:
# Text(0, 0.5, 'Job Category')

# %% [markdown]
# It is clear from the above plot that more than 50% subscriptions are done by students and retired clients, just as visualized previously.

# %%
#Visualize the subscription and contact rate by month

count_month_response = pd.crosstab(df7['response'],df7['month_int']).apply(lambda x: x/x.sum() * 100)
count_month_response = count_month_response.transpose()

# %%
month = pd.DataFrame(df7['month_int'].value_counts())
month['Contacts'] = month['month_int']*100/month['month_int'].sum()
month['Subscriptions'] = count_month_response['yes']
month.drop('month_int',axis = 1,inplace = True)

month['Month'] = [5,7,8,6,11,4,2,1,10,9,3,12]
month = month.sort_values('Month',ascending = True)

# %%
plot_month = month[['Subscriptions','Contacts']].plot(kind ='line',
                                                          figsize = (10,10),
                                                          marker = 'o')

plt.title('Subscription vs. Contact Rate by Month')
plt.ylabel('Subscription and Contact Rate')
plt.xlabel('Month')

ticks = np.arange(1,13,1)
plt.xticks(ticks)

# Annotation: peak of contact
y = month['Contacts'].max()
x = month['Contacts'].idxmax()
plt.annotate('May: Peak of contact', xy=(x+0.1, y+0.1), xytext=(x+1,y+4), arrowprops=dict(facecolor='black', headwidth=6, width=1, headlength=4), horizontalalignment='left', verticalalignment='top')

# Annotation: peak of subscription rate
y = month['Subscriptions'].max()
x = month['Subscriptions'].idxmax()
plt.annotate('March: Peak Subscription rate', xy=(x+0.1, y+0.1), xytext=(x+1,y+1), arrowprops=dict(facecolor='black', headwidth=6, width=1, headlength=4), horizontalalignment='left', verticalalignment='top')

plt.show()

# %% [markdown]
# MACHINE LEARNING CLASSIFICATION

# %% [markdown]
# The main objective of this project is to identify the most responsive customers before the marketing campaign so that the bank will be able to efficiently reach out to them, saving time and marketing resources. To achieve this objective, classification algorithms will be employed. By analyzing customer statistics, a classification model will be built to classify all clients into two groups: "yes" to term deposits and "no" to term deposits.

# %%
#Load Cleaned Dataset

ds = pd.read_csv("/Users/Lenovo/Desktop/Machine learning internship/Project/bank_cleaned.csv")
ds = ds.drop(['Unnamed: 0'], axis=1)

# %%
ds.head()
# Out:
#    age           job  marital  education default  balance housing loan  day  \
# 0   58    management  married   tertiary      no     2143     yes   no    5
# 1   44    technician   single  secondary      no       29     yes   no    5
# 2   33  entrepreneur  married  secondary      no        2     yes  yes    5
# 3   35    management  married   tertiary      no      231     yes   no    5
# 4   28    management   single   tertiary      no      447     yes  yes    5
#
#   month  duration  campaign  pdays  previous poutcome response  \
# 0   may      4.35         1     -1         0  unknown       no
# 1   may      2.52         1     -1         0  unknown       no
# 2   may      1.27         1     -1         0  unknown       no
# 3   may      2.32         1     -1         0  unknown       no
# 4   may      3.62         1     -1         0  unknown       no
#
#    response_binary
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %% [markdown]
# Prepare data for classification
#
# 1.Select variables relevant to customers

# %%
ds.drop(['marital'],axis=1, inplace=True)
ds1 = ds1.iloc[:, 0:7]

# %%
ds1.head(50)
# Out:
#     age            job  education default  balance housing loan
# 0    58     management   tertiary      no     2143     yes   no
# 1    44     technician  secondary      no       29     yes   no
# 2    33   entrepreneur  secondary      no        2     yes  yes
# 3    35     management   tertiary      no      231     yes   no
# 4    28     management   tertiary      no      447     yes  yes
# 5    42   entrepreneur   tertiary     yes        2     yes   no
# 6    58        retired    primary      no      121     yes   no
# 7    43     technician  secondary      no      593     yes   no
# 8    41         admin.  secondary      no      270     yes   no
# 9    29         admin.  secondary      no      390     yes   no
# 10   53     technician  secondary      no        6     yes   no
# 11   57       services  secondary      no      162     yes   no
# 12   51        retired    primary      no      229     yes   no
# 13   57    blue-collar    primary      no       52     yes   no
# ...

# %% [markdown]
# 2.Transform categorical into dummy variables
#
# Since machine learning algorithms only take numerical values, all five categorical variables (job, education, default, housing and loan) are transformed into dummy variables/qualitative variables.

# %%
ds2 = pd.get_dummies(ds1, columns = ['job'])
ds2 = pd.get_dummies(ds2, columns = ['education'])
ds2['housing'] = ds2['housing'].map({'yes': 1, 'no': 0})
ds2['default'] = ds2['default'].map({'yes': 1, 'no': 0})
ds2['loan'] = ds2['loan'].map({'yes': 1, 'no': 0})

# %%
ds_response = pd.DataFrame(ds['response_binary'])
ds2 = pd.merge(ds2, ds_response, left_index = True, right_index = True)

# %% [markdown]
# 3.Feature Selection

# %%
array = ds2.values
x = array[:,0:-1]
y = array[:,-1] #target :response_binary

# %% [markdown]
# 4.Train_test_split

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

test_size= 0.20
seed = 7
X_train, X_test, Y_train, Y_test= train_test_split(x, y, test_size=test_size, random_state=seed)

# %% [markdown]
# Compare classification algorithms
#
#
#
# Four different classification algorithms (Logistic Regression, K-Neighbors Classifier, Decision Tree Classifier, and Gaussian NB) are run on the dataset and the best-performing one will be used to build the classification model.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

# %%
models = []
models.append(('LF', LogisticRegression()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))

# %%
results = []
names = []

for name, model in models:
    # define how to split off validation data ('kfold' how many folds)
    kfold = KFold(n_splits=10, random_state=seed)    
    # train the model
    cv_outcome = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')    
    results.append(cv_outcome)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_outcome.mean(), cv_outcome.std())
    print(msg)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
fig = plt.figure()
fig.suptitle('Perfomance of Classification Algorithms')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %% [markdown]
# Among the 4 classification algorithms, logistic regression is the best model with an accuracy of 88%.
#
# Test LR model on test set

# %%
LR = LogisticRegression()
LR.fit(X_train, Y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
#Evaluate LR Model

predictions = LR.predict(X_test)

# Accuracy Score 
print(accuracy_score(Y_test, predictions))
# Out:
# 0.890806708287428

# %% [markdown]
# Accuracy score is the percentage of correct predictions out of all predictions made. The LR algorithm achieves an accuracy of 89.08%, suggesting high level of strength of this model to classify the customer response given all the defined customer features.

# %%
# Confusion Matrix 
from sklearn.metrics import confusion_matrix
import pylab as pl

print(confusion_matrix(Y_test, predictions))

conf_mat = confusion_matrix(Y_test, predictions)
pl.matshow(conf_mat)
pl.title('Confusion matrix of the classifier')
pl.colorbar()
pl.show()
# Out:
# [[7277    1]
#  [ 891    0]]

# %% [markdown]
# However, the result of accuracy score can possibly yield misleading result if the data set is unbalanced, because the number of observations in different classes largely vary.
#
# A confusion matrix gives a detailed breakdown of prediction result and error types. Each cell in the matrix represents a combination of instances of the predicted response and the actual response. In the test set, the matrix proves that the algorithm performed well because most test results (7277 True Positive predictions) locate on the diagonal cells which represent correct predictions. 891 tests (False negative) predicted the bank’s client would subscribe to the term deposit but they actually did not.
#
# A problem revealed by this confusion matrix is that the dataset is highly unbalanced, with nearly all client actually decline to subscribe. This infers that the accuracy score is biased, and further evaluation should be carried out to determine the accuracy of logistic regression model.

# %%
# Classification Report
from sklearn.metrics import classification_report
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      7278
#            1       0.00      0.00      0.00       891
#
#    micro avg       0.89      0.89      0.89      8169
#    macro avg       0.45      0.50      0.47      8169
# weighted avg       0.79      0.89      0.84      8169

# %% [markdown]
# Classification report shows the precision, recall, F1 and support scores for the LR classification model.
#
#     Precision of 0 (the client said no) represents that for all instances predicted as no subscription, the percentage of clients that actually said no is 89%.
#     Recall is the ability of a classifier to find all positive instances. Recall of 0 indicates that for all clients that actually said no, the model predicts 100% correctly that they would decline the offer.
#
# In general, the report shows that LR model has great predictive power to identify the customers who would not subscribe to the term deposit.
